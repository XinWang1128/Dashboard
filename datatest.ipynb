# %%
import pandas as pd
import numpy as np

# %%
#df= pd.read_excel("C:/Users/24634/Desktop/Dashboard/Dashboard/Input/2025_06_DUVAExport_KOSIS_new.xlsx")
geb = pd.read_excel("C:/Users/24634/Desktop/Dashboard/Dashboard/Input/Gebaud.xlsx")

# %%
geb_500= geb.sample(n=500)
geb_5000= geb.sample(n=5000)

# %%
df_50.to_csv('C:/Users/24634/Desktop/Dashboard/Dashboard/dashboard/output/k50.csv')
df_500.to_csv('C:/Users/24634/Desktop/Dashboard/Dashboard/dashboard/output/k500.csv')
df_5000.to_csv('C:/Users/24634/Desktop/Dashboard/Dashboard/dashboard/output/k5000.csv')
